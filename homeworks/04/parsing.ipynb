# %%
Фамилия, имя: Сидорова Анна. Парсинг т-прогера

# %%
import requests #библиотека для упрощения HTTP-запросов
from bs4 import BeautifulSoup
import json
import re

# %%
#Сделаем простой запрос (+ подмена headers на всякий случай, чтоб не быть забаненными)
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}
r = requests.get("https://tproger.ru/", headers=headers, timeout=5)
print(r.ok)
print(r.status_code) #если 200, все норм
print(r.cookies)
# Out:
# True
# 200
# <RequestsCookieJar[<Cookie __cfduid=d15607ee5899b5a1f4d1164ba64428d631541425290 for .tproger.ru/>]>

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html
# id="ie8" lang="ru-RU" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article#  profile: http://ogp.me/ns/profile# fb: http://ogp.me/ns/fb#">
# <![endif]-->
# <!--[if !(IE 8) ]><!--><html lang="ru-RU" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article#  profile: http://ogp.me/ns/profile# fb: http://ogp.me/ns/fb#">
# ...

# %%
soup = BeautifulSoup(r.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html
# id="ie8" lang="ru-RU" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article#  profile: http://ogp.me/ns/profile# fb: http://ogp.me/ns/fb#">
# <![endif]-->
# <!--[if !(IE 8) ]><!--><html lang="ru-RU" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article#  profile: http://ogp.me/ns/profile# fb: http://ogp.me/ns/fb#">
# ...

# %%
print(soup.attrs)
# Out:
# {}

# %%
#Найдем элементы в теге div. При этом будут найдены все теги, любой вложенности
print(soup.find_all('div'))
# Out:
# [<div><img alt="" src="https://mc.yandex.ru/watch/27485085" style="position:absolute; left:-9999px;"/></div>, <div class="event-frozen" id="eventfrozen"></div>, <div class="site" id="page">
# <header class="header_normal" id="masthead" role="banner"><div class="image-overflow"><div class="header-background-image"></div></div><div class="row-fluid top-duft-punk" style="height:auto;"><div class="container"><div class="banner-overlay"></div><div class="text_logo">
# <a>
# <img alt="Tproger" id="logo" src="https://cdn.tproger.ru/wp-content/themes/bliss/assets/img/tp-circle2.png"/>
# <span class="brand_name">
# Tproger
# </span>
# ...

# %%
print(soup.find_all('div')[1].attrs)
# Out:
# {'id': 'eventfrozen', 'class': ['event-frozen']}

# %%
soup.findAll("div", attrs={"class": ["titles"]})
# Out:
# []

# %%
#tag = soup.b
# Out:
# NoneType
